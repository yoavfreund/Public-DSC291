# %%
import pickle as pk
import numpy as np
from glob import glob

# %%
data_dir="/dev/shm/data"
# !mkdir $data_dir
#!rm $data_dir/patches*.npz
# !ls -lrt $data_dir/patches*.npz
# Out:
# mkdir: cannot create directory ‘/dev/shm/data’: File exists
# ls: cannot access '/dev/shm/data/patches*.npz': No such file or directory

# %%
# run on aws
s3files=!aws s3 ls s3://mousebraindata-open/MD657/patches/
    
patches=np.zeros([0])
i=0
for line in s3files:
    parts=line.split()
    filename=parts[-1]
    print(filename)
    # !aws s3 cp s3://mousebraindata-open/MD657/patches/$filename $data_dir

    file=data_dir+"/"+filename
    print(file)
    content=np.load(file)
    if patches.shape[0]==0:
        patches=content['Vout']
    else:
        patches=np.concatenate([patches,content['Vout']])
    print(i,patches.shape)
    i+=1
    # !rm $file
# Out:
# patches0.npz
# download: s3://mousebraindata-open/MD657/patches/patches0.npz to ../../../../dev/shm/data/patches0.npz
# /dev/shm/data/patches0.npz
# 0 (107656, 41, 41)
# patches1.npz
# download: s3://mousebraindata-open/MD657/patches/patches1.npz to ../../../../dev/shm/data/patches1.npz
# /dev/shm/data/patches1.npz
# 1 (203693, 41, 41)
# patches10.npz
# download: s3://mousebraindata-open/MD657/patches/patches10.npz to ../../../../dev/shm/data/patches10.npz
# /dev/shm/data/patches10.npz
# 2 (306360, 41, 41)
# patches100.npz
# download: s3://mousebraindata-open/MD657/patches/patches100.npz to ../../../../dev/shm/data/patches100.npz
# /dev/shm/data/patches100.npz
# 3 (426375, 41, 41)
# patches101.npz
# download: s3://mousebraindata-open/MD657/patches/patches101.npz to ../../../../dev/shm/data/patches101.npz
# /dev/shm/data/patches101.npz
# 4 (533851, 41, 41)
# patches102.npz
# download: s3://mousebraindata-open/MD657/patches/patches102.npz to ../../../../dev/shm/data/patches102.npz
# /dev/shm/data/patches102.npz
# 5 (632878, 41, 41)
# patches103.npz
# download: s3://mousebraindata-open/MD657/patches/patches103.npz to ../../../../dev/shm/data/patches103.npz
# /dev/shm/data/patches103.npz
# 6 (740032, 41, 41)
# patches104.npz
# download: s3://mousebraindata-open/MD657/patches/patches104.npz to ../../../../dev/shm/data/patches104.npz
# /dev/shm/data/patches104.npz
# 7 (833615, 41, 41)
# patches105.npz
# download: s3://mousebraindata-open/MD657/patches/patches105.npz to ../../../../dev/shm/data/patches105.npz
# /dev/shm/data/patches105.npz
# 8 (926437, 41, 41)
# patches106.npz
# download: s3://mousebraindata-open/MD657/patches/patches106.npz to ../../../../dev/shm/data/patches106.npz
# /dev/shm/data/patches106.npz
# 9 (1007867, 41, 41)
# patches107.npz
# download: s3://mousebraindata-open/MD657/patches/patches107.npz to ../../../../dev/shm/data/patches107.npz
# /dev/shm/data/patches107.npz
# 10 (1095493, 41, 41)
# patches108.npz
# download: s3://mousebraindata-open/MD657/patches/patches108.npz to ../../../../dev/shm/data/patches108.npz
# /dev/shm/data/patches108.npz
# 11 (1182746, 41, 41)
# patches109.npz
# download: s3://mousebraindata-open/MD657/patches/patches109.npz to ../../../../dev/shm/data/patches109.npz
# /dev/shm/data/patches109.npz
# 12 (1262903, 41, 41)
# patches11.npz
# download: s3://mousebraindata-open/MD657/patches/patches11.npz to ../../../../dev/shm/data/patches11.npz
# /dev/shm/data/patches11.npz
# 13 (1358469, 41, 41)
# patches110.npz
# download: s3://mousebraindata-open/MD657/patches/patches110.npz to ../../../../dev/shm/data/patches110.npz
# /dev/shm/data/patches110.npz
# 14 (1436670, 41, 41)
# patches111.npz
# download: s3://mousebraindata-open/MD657/patches/patches111.npz to ../../../../dev/shm/data/patches111.npz
# /dev/shm/data/patches111.npz
# 15 (1546794, 41, 41)
# patches112.npz
# download: s3://mousebraindata-open/MD657/patches/patches112.npz to ../../../../dev/shm/data/patches112.npz
# /dev/shm/data/patches112.npz
# 16 (1652441, 41, 41)
# patches113.npz
# download: s3://mousebraindata-open/MD657/patches/patches113.npz to ../../../../dev/shm/data/patches113.npz
# /dev/shm/data/patches113.npz
# 17 (1748602, 41, 41)
# patches114.npz
# download: s3://mousebraindata-open/MD657/patches/patches114.npz to ../../../../dev/shm/data/patches114.npz
# /dev/shm/data/patches114.npz
# 18 (1844020, 41, 41)
# patches115.npz
# download: s3://mousebraindata-open/MD657/patches/patches115.npz to ../../../../dev/shm/data/patches115.npz
# /dev/shm/data/patches115.npz
# 19 (1928366, 41, 41)
# patches116.npz
# download: s3://mousebraindata-open/MD657/patches/patches116.npz to ../../../../dev/shm/data/patches116.npz
# /dev/shm/data/patches116.npz
# 20 (2027951, 41, 41)
# patches117.npz
# download: s3://mousebraindata-open/MD657/patches/patches117.npz to ../../../../dev/shm/data/patches117.npz
# /dev/shm/data/patches117.npz
# 21 (2119602, 41, 41)
# patches118.npz
# download: s3://mousebraindata-open/MD657/patches/patches118.npz to ../../../../dev/shm/data/patches118.npz
# /dev/shm/data/patches118.npz
# 22 (2209124, 41, 41)
# patches119.npz
# download: s3://mousebraindata-open/MD657/patches/patches119.npz to ../../../../dev/shm/data/patches119.npz
# /dev/shm/data/patches119.npz
# 23 (2291566, 41, 41)
# patches12.npz
# download: s3://mousebraindata-open/MD657/patches/patches12.npz to ../../../../dev/shm/data/patches12.npz
# /dev/shm/data/patches12.npz
# 24 (2402567, 41, 41)
# patches120.npz
# download: s3://mousebraindata-open/MD657/patches/patches120.npz to ../../../../dev/shm/data/patches120.npz
# /dev/shm/data/patches120.npz
# 25 (2480594, 41, 41)
# patches121.npz
# download: s3://mousebraindata-open/MD657/patches/patches121.npz to ../../../../dev/shm/data/patches121.npz
# /dev/shm/data/patches121.npz
# 26 (2572547, 41, 41)
# patches122.npz
# download: s3://mousebraindata-open/MD657/patches/patches122.npz to ../../../../dev/shm/data/patches122.npz
# /dev/shm/data/patches122.npz
# 27 (2661744, 41, 41)
# patches123.npz
# download: s3://mousebraindata-open/MD657/patches/patches123.npz to ../../../../dev/shm/data/patches123.npz
# /dev/shm/data/patches123.npz
# 28 (2756738, 41, 41)
# patches124.npz
# download: s3://mousebraindata-open/MD657/patches/patches124.npz to ../../../../dev/shm/data/patches124.npz
# /dev/shm/data/patches124.npz
# 29 (2861292, 41, 41)
# patches125.npz
# download: s3://mousebraindata-open/MD657/patches/patches125.npz to ../../../../dev/shm/data/patches125.npz
# /dev/shm/data/patches125.npz
# 30 (2939691, 41, 41)
# patches126.npz
# download: s3://mousebraindata-open/MD657/patches/patches126.npz to ../../../../dev/shm/data/patches126.npz
# /dev/shm/data/patches126.npz
# 31 (3045811, 41, 41)
# patches127.npz
# download: s3://mousebraindata-open/MD657/patches/patches127.npz to ../../../../dev/shm/data/patches127.npz
# /dev/shm/data/patches127.npz
# 32 (3153309, 41, 41)
# patches128.npz
# download: s3://mousebraindata-open/MD657/patches/patches128.npz to ../../../../dev/shm/data/patches128.npz
# /dev/shm/data/patches128.npz
# 33 (3270881, 41, 41)
# patches129.npz
# download: s3://mousebraindata-open/MD657/patches/patches129.npz to ../../../../dev/shm/data/patches129.npz
# /dev/shm/data/patches129.npz
# 34 (3387127, 41, 41)
# patches13.npz
# download: s3://mousebraindata-open/MD657/patches/patches13.npz to ../../../../dev/shm/data/patches13.npz
# /dev/shm/data/patches13.npz
# 35 (3499015, 41, 41)
# patches130.npz
# download: s3://mousebraindata-open/MD657/patches/patches130.npz to ../../../../dev/shm/data/patches130.npz
# /dev/shm/data/patches130.npz
# 36 (3578865, 41, 41)
# patches131.npz
# download: s3://mousebraindata-open/MD657/patches/patches131.npz to ../../../../dev/shm/data/patches131.npz
# /dev/shm/data/patches131.npz
# 37 (3659956, 41, 41)
# patches132.npz
# download: s3://mousebraindata-open/MD657/patches/patches132.npz to ../../../../dev/shm/data/patches132.npz
# /dev/shm/data/patches132.npz
# 38 (3767958, 41, 41)
# patches133.npz
# download: s3://mousebraindata-open/MD657/patches/patches133.npz to ../../../../dev/shm/data/patches133.npz
# /dev/shm/data/patches133.npz
# 39 (3853049, 41, 41)
# patches134.npz
# download: s3://mousebraindata-open/MD657/patches/patches134.npz to ../../../../dev/shm/data/patches134.npz
# /dev/shm/data/patches134.npz
# 40 (3941424, 41, 41)
# patches135.npz
# download: s3://mousebraindata-open/MD657/patches/patches135.npz to ../../../../dev/shm/data/patches135.npz
# /dev/shm/data/patches135.npz
# 41 (4029693, 41, 41)
# patches136.npz
# download: s3://mousebraindata-open/MD657/patches/patches136.npz to ../../../../dev/shm/data/patches136.npz
# /dev/shm/data/patches136.npz
# 42 (4117184, 41, 41)
# patches137.npz
# download: s3://mousebraindata-open/MD657/patches/patches137.npz to ../../../../dev/shm/data/patches137.npz
# /dev/shm/data/patches137.npz
# 43 (4211546, 41, 41)
# patches138.npz
# download: s3://mousebraindata-open/MD657/patches/patches138.npz to ../../../../dev/shm/data/patches138.npz
# /dev/shm/data/patches138.npz
# 44 (4311910, 41, 41)
# patches139.npz
# download: s3://mousebraindata-open/MD657/patches/patches139.npz to ../../../../dev/shm/data/patches139.npz
# /dev/shm/data/patches139.npz
# 45 (4410376, 41, 41)
# patches14.npz
# download: s3://mousebraindata-open/MD657/patches/patches14.npz to ../../../../dev/shm/data/patches14.npz
# /dev/shm/data/patches14.npz
# 46 (4514630, 41, 41)
# patches140.npz
# download: s3://mousebraindata-open/MD657/patches/patches140.npz to ../../../../dev/shm/data/patches140.npz
# /dev/shm/data/patches140.npz
# 47 (4616055, 41, 41)
# patches141.npz
# download: s3://mousebraindata-open/MD657/patches/patches141.npz to ../../../../dev/shm/data/patches141.npz
# /dev/shm/data/patches141.npz
# 48 (4696593, 41, 41)
# patches142.npz
# download: s3://mousebraindata-open/MD657/patches/patches142.npz to ../../../../dev/shm/data/patches142.npz
# /dev/shm/data/patches142.npz
# 49 (4795287, 41, 41)
# patches143.npz
# download: s3://mousebraindata-open/MD657/patches/patches143.npz to ../../../../dev/shm/data/patches143.npz
# /dev/shm/data/patches143.npz
# 50 (4899826, 41, 41)
# patches144.npz
# download: s3://mousebraindata-open/MD657/patches/patches144.npz to ../../../../dev/shm/data/patches144.npz
# /dev/shm/data/patches144.npz
# 51 (5003706, 41, 41)
# patches145.npz
# download: s3://mousebraindata-open/MD657/patches/patches145.npz to ../../../../dev/shm/data/patches145.npz
# /dev/shm/data/patches145.npz
# 52 (5112427, 41, 41)
# patches146.npz
# download: s3://mousebraindata-open/MD657/patches/patches146.npz to ../../../../dev/shm/data/patches146.npz
# /dev/shm/data/patches146.npz
# 53 (5227380, 41, 41)
# patches147.npz
# download: s3://mousebraindata-open/MD657/patches/patches147.npz to ../../../../dev/shm/data/patches147.npz
# /dev/shm/data/patches147.npz
# 54 (5329450, 41, 41)
# patches148.npz
# download: s3://mousebraindata-open/MD657/patches/patches148.npz to ../../../../dev/shm/data/patches148.npz
# /dev/shm/data/patches148.npz
# 55 (5446948, 41, 41)
# patches149.npz
# download: s3://mousebraindata-open/MD657/patches/patches149.npz to ../../../../dev/shm/data/patches149.npz
# /dev/shm/data/patches149.npz
# 56 (5561654, 41, 41)
# patches15.npz
# download: s3://mousebraindata-open/MD657/patches/patches15.npz to ../../../../dev/shm/data/patches15.npz
# /dev/shm/data/patches15.npz
# 57 (5674672, 41, 41)
# patches150.npz
# download: s3://mousebraindata-open/MD657/patches/patches150.npz to ../../../../dev/shm/data/patches150.npz
# /dev/shm/data/patches150.npz
# 58 (5793090, 41, 41)
# patches151.npz
# download: s3://mousebraindata-open/MD657/patches/patches151.npz to ../../../../dev/shm/data/patches151.npz
# /dev/shm/data/patches151.npz
# 59 (5913073, 41, 41)
# patches152.npz
# download: s3://mousebraindata-open/MD657/patches/patches152.npz to ../../../../dev/shm/data/patches152.npz
# /dev/shm/data/patches152.npz
# 60 (6020010, 41, 41)
# patches153.npz
# download: s3://mousebraindata-open/MD657/patches/patches153.npz to ../../../../dev/shm/data/patches153.npz
# /dev/shm/data/patches153.npz
# 61 (6140096, 41, 41)
# patches154.npz
# download: s3://mousebraindata-open/MD657/patches/patches154.npz to ../../../../dev/shm/data/patches154.npz
# /dev/shm/data/patches154.npz
# 62 (6262352, 41, 41)
# patches155.npz
# download: s3://mousebraindata-open/MD657/patches/patches155.npz to ../../../../dev/shm/data/patches155.npz
# /dev/shm/data/patches155.npz
# 63 (6385143, 41, 41)
# patches156.npz
# download: s3://mousebraindata-open/MD657/patches/patches156.npz to ../../../../dev/shm/data/patches156.npz
# /dev/shm/data/patches156.npz
# 64 (6520994, 41, 41)
# patches157.npz
# download: s3://mousebraindata-open/MD657/patches/patches157.npz to ../../../../dev/shm/data/patches157.npz
# /dev/shm/data/patches157.npz
# 65 (6654922, 41, 41)
# patches158.npz
# download: s3://mousebraindata-open/MD657/patches/patches158.npz to ../../../../dev/shm/data/patches158.npz
# /dev/shm/data/patches158.npz
# 66 (6792852, 41, 41)
# patches16.npz
# download: s3://mousebraindata-open/MD657/patches/patches16.npz to ../../../../dev/shm/data/patches16.npz
# /dev/shm/data/patches16.npz
# 67 (6891377, 41, 41)
# patches17.npz
# download: s3://mousebraindata-open/MD657/patches/patches17.npz to ../../../../dev/shm/data/patches17.npz
# /dev/shm/data/patches17.npz
# 68 (7014003, 41, 41)
# patches18.npz
# download: s3://mousebraindata-open/MD657/patches/patches18.npz to ../../../../dev/shm/data/patches18.npz
# /dev/shm/data/patches18.npz
# 69 (7137660, 41, 41)
# patches19.npz
# download: s3://mousebraindata-open/MD657/patches/patches19.npz to ../../../../dev/shm/data/patches19.npz
# /dev/shm/data/patches19.npz
# 70 (7262117, 41, 41)
# patches2.npz
# download: s3://mousebraindata-open/MD657/patches/patches2.npz to ../../../../dev/shm/data/patches2.npz
# /dev/shm/data/patches2.npz
# 71 (7346807, 41, 41)
# patches20.npz
# download: s3://mousebraindata-open/MD657/patches/patches20.npz to ../../../../dev/shm/data/patches20.npz
# /dev/shm/data/patches20.npz
# 72 (7469249, 41, 41)
# patches21.npz
# download: s3://mousebraindata-open/MD657/patches/patches21.npz to ../../../../dev/shm/data/patches21.npz
# /dev/shm/data/patches21.npz
# 73 (7592889, 41, 41)
# patches22.npz
# download: s3://mousebraindata-open/MD657/patches/patches22.npz to ../../../../dev/shm/data/patches22.npz
# /dev/shm/data/patches22.npz
# 74 (7719854, 41, 41)
# patches23.npz
# download: s3://mousebraindata-open/MD657/patches/patches23.npz to ../../../../dev/shm/data/patches23.npz
# /dev/shm/data/patches23.npz
# 75 (7835118, 41, 41)
# patches24.npz
# download: s3://mousebraindata-open/MD657/patches/patches24.npz to ../../../../dev/shm/data/patches24.npz
# /dev/shm/data/patches24.npz
# 76 (7945206, 41, 41)
# patches25.npz
# download: s3://mousebraindata-open/MD657/patches/patches25.npz to ../../../../dev/shm/data/patches25.npz
# /dev/shm/data/patches25.npz
# 77 (8086819, 41, 41)
# patches26.npz
# download: s3://mousebraindata-open/MD657/patches/patches26.npz to ../../../../dev/shm/data/patches26.npz
# /dev/shm/data/patches26.npz
# 78 (8177413, 41, 41)
# patches27.npz
# download: s3://mousebraindata-open/MD657/patches/patches27.npz to ../../../../dev/shm/data/patches27.npz
# /dev/shm/data/patches27.npz
# 79 (8287634, 41, 41)
# patches28.npz
# download: s3://mousebraindata-open/MD657/patches/patches28.npz to ../../../../dev/shm/data/patches28.npz
# /dev/shm/data/patches28.npz
# 80 (8430334, 41, 41)
# patches29.npz
# download: s3://mousebraindata-open/MD657/patches/patches29.npz to ../../../../dev/shm/data/patches29.npz
# /dev/shm/data/patches29.npz
# 81 (8584945, 41, 41)
# patches3.npz
# download: s3://mousebraindata-open/MD657/patches/patches3.npz to ../../../../dev/shm/data/patches3.npz
# /dev/shm/data/patches3.npz
# 82 (8665617, 41, 41)
# patches30.npz
# download: s3://mousebraindata-open/MD657/patches/patches30.npz to ../../../../dev/shm/data/patches30.npz
# /dev/shm/data/patches30.npz
# 83 (8794923, 41, 41)
# patches31.npz
# download: s3://mousebraindata-open/MD657/patches/patches31.npz to ../../../../dev/shm/data/patches31.npz
# /dev/shm/data/patches31.npz
# 84 (8874060, 41, 41)
# patches32.npz
# download: s3://mousebraindata-open/MD657/patches/patches32.npz to ../../../../dev/shm/data/patches32.npz
# /dev/shm/data/patches32.npz
# 85 (8958708, 41, 41)
# patches33.npz
# download: s3://mousebraindata-open/MD657/patches/patches33.npz to ../../../../dev/shm/data/patches33.npz
# /dev/shm/data/patches33.npz
# 86 (9039784, 41, 41)
# patches34.npz
# download: s3://mousebraindata-open/MD657/patches/patches34.npz to ../../../../dev/shm/data/patches34.npz
# /dev/shm/data/patches34.npz
# 87 (9122706, 41, 41)
# patches35.npz
# download: s3://mousebraindata-open/MD657/patches/patches35.npz to ../../../../dev/shm/data/patches35.npz
# /dev/shm/data/patches35.npz
# 88 (9205769, 41, 41)
# patches36.npz
# download: s3://mousebraindata-open/MD657/patches/patches36.npz to ../../../../dev/shm/data/patches36.npz
# /dev/shm/data/patches36.npz
# 89 (9363914, 41, 41)
# patches37.npz
# download: s3://mousebraindata-open/MD657/patches/patches37.npz to ../../../../dev/shm/data/patches37.npz
# /dev/shm/data/patches37.npz
# 90 (9445483, 41, 41)
# patches38.npz
# download: s3://mousebraindata-open/MD657/patches/patches38.npz to ../../../../dev/shm/data/patches38.npz
# /dev/shm/data/patches38.npz
# 91 (9528455, 41, 41)
# patches39.npz
# download: s3://mousebraindata-open/MD657/patches/patches39.npz to ../../../../dev/shm/data/patches39.npz
# /dev/shm/data/patches39.npz
# 92 (9610990, 41, 41)
# patches4.npz
# download: s3://mousebraindata-open/MD657/patches/patches4.npz to ../../../../dev/shm/data/patches4.npz
# /dev/shm/data/patches4.npz
# 93 (9700261, 41, 41)
# patches40.npz
# download: s3://mousebraindata-open/MD657/patches/patches40.npz to ../../../../dev/shm/data/patches40.npz
# /dev/shm/data/patches40.npz
# 94 (9788054, 41, 41)
# patches41.npz
# download: s3://mousebraindata-open/MD657/patches/patches41.npz to ../../../../dev/shm/data/patches41.npz
# /dev/shm/data/patches41.npz
# 95 (9873090, 41, 41)
# patches42.npz
# download: s3://mousebraindata-open/MD657/patches/patches42.npz to ../../../../dev/shm/data/patches42.npz
# /dev/shm/data/patches42.npz
# 96 (9959052, 41, 41)
# patches43.npz
# download: s3://mousebraindata-open/MD657/patches/patches43.npz to ../../../../dev/shm/data/patches43.npz
# /dev/shm/data/patches43.npz
# 97 (10107413, 41, 41)
# patches44.npz
# download: s3://mousebraindata-open/MD657/patches/patches44.npz to ../../../../dev/shm/data/patches44.npz
# /dev/shm/data/patches44.npz
# 98 (10189406, 41, 41)
# patches45.npz
# download: s3://mousebraindata-open/MD657/patches/patches45.npz to ../../../../dev/shm/data/patches45.npz
# /dev/shm/data/patches45.npz
# 99 (10275875, 41, 41)
# patches46.npz
# download: s3://mousebraindata-open/MD657/patches/patches46.npz to ../../../../dev/shm/data/patches46.npz
# /dev/shm/data/patches46.npz
# 100 (10366680, 41, 41)
# patches47.npz
# download: s3://mousebraindata-open/MD657/patches/patches47.npz to ../../../../dev/shm/data/patches47.npz
# /dev/shm/data/patches47.npz
# 101 (10460523, 41, 41)
# patches48.npz
# download: s3://mousebraindata-open/MD657/patches/patches48.npz to ../../../../dev/shm/data/patches48.npz
# /dev/shm/data/patches48.npz
# 102 (10549070, 41, 41)
# patches49.npz
# download: s3://mousebraindata-open/MD657/patches/patches49.npz to ../../../../dev/shm/data/patches49.npz
# /dev/shm/data/patches49.npz
# 103 (10701064, 41, 41)
# patches5.npz
# download: s3://mousebraindata-open/MD657/patches/patches5.npz to ../../../../dev/shm/data/patches5.npz
# /dev/shm/data/patches5.npz
# 104 (10791815, 41, 41)
# patches50.npz
# download: s3://mousebraindata-open/MD657/patches/patches50.npz to ../../../../dev/shm/data/patches50.npz
# /dev/shm/data/patches50.npz
# 105 (10903537, 41, 41)
# patches51.npz
# download: s3://mousebraindata-open/MD657/patches/patches51.npz to ../../../../dev/shm/data/patches51.npz
# /dev/shm/data/patches51.npz
# 106 (11000459, 41, 41)
# patches52.npz
# download: s3://mousebraindata-open/MD657/patches/patches52.npz to ../../../../dev/shm/data/patches52.npz
# /dev/shm/data/patches52.npz
# 107 (11088923, 41, 41)
# patches53.npz
# download: s3://mousebraindata-open/MD657/patches/patches53.npz to ../../../../dev/shm/data/patches53.npz
# /dev/shm/data/patches53.npz
# 108 (11178633, 41, 41)
# patches54.npz
# download: s3://mousebraindata-open/MD657/patches/patches54.npz to ../../../../dev/shm/data/patches54.npz
# /dev/shm/data/patches54.npz
# 109 (11270010, 41, 41)
# patches55.npz
# download: s3://mousebraindata-open/MD657/patches/patches55.npz to ../../../../dev/shm/data/patches55.npz
# /dev/shm/data/patches55.npz
# 110 (11359488, 41, 41)
# patches56.npz
# download: s3://mousebraindata-open/MD657/patches/patches56.npz to ../../../../dev/shm/data/patches56.npz
# /dev/shm/data/patches56.npz
# 111 (11446228, 41, 41)
# patches57.npz
# download: s3://mousebraindata-open/MD657/patches/patches57.npz to ../../../../dev/shm/data/patches57.npz
# /dev/shm/data/patches57.npz
# 112 (11533950, 41, 41)
# patches58.npz
# download: s3://mousebraindata-open/MD657/patches/patches58.npz to ../../../../dev/shm/data/patches58.npz
# /dev/shm/data/patches58.npz
# 113 (11618853, 41, 41)
# patches59.npz
# download: s3://mousebraindata-open/MD657/patches/patches59.npz to ../../../../dev/shm/data/patches59.npz
# /dev/shm/data/patches59.npz
# 114 (11706164, 41, 41)
# patches60.npz
# download: s3://mousebraindata-open/MD657/patches/patches60.npz to ../../../../dev/shm/data/patches60.npz
# /dev/shm/data/patches60.npz
# 115 (11792722, 41, 41)
# patches61.npz
# download: s3://mousebraindata-open/MD657/patches/patches61.npz to ../../../../dev/shm/data/patches61.npz
# /dev/shm/data/patches61.npz
# 116 (11890623, 41, 41)
# patches62.npz
# download: s3://mousebraindata-open/MD657/patches/patches62.npz to ../../../../dev/shm/data/patches62.npz
# /dev/shm/data/patches62.npz
# 117 (12045220, 41, 41)
# patches63.npz
# download: s3://mousebraindata-open/MD657/patches/patches63.npz to ../../../../dev/shm/data/patches63.npz
# /dev/shm/data/patches63.npz
# 118 (12132522, 41, 41)
# patches64.npz
# download: s3://mousebraindata-open/MD657/patches/patches64.npz to ../../../../dev/shm/data/patches64.npz
# /dev/shm/data/patches64.npz
# 119 (12215798, 41, 41)
# patches65.npz
# download: s3://mousebraindata-open/MD657/patches/patches65.npz to ../../../../dev/shm/data/patches65.npz
# /dev/shm/data/patches65.npz
# 120 (12295481, 41, 41)
# patches66.npz
# download: s3://mousebraindata-open/MD657/patches/patches66.npz to ../../../../dev/shm/data/patches66.npz
# /dev/shm/data/patches66.npz
# 121 (12385274, 41, 41)
# patches67.npz
# download: s3://mousebraindata-open/MD657/patches/patches67.npz to ../../../../dev/shm/data/patches67.npz
# /dev/shm/data/patches67.npz
# 122 (12473969, 41, 41)
# patches68.npz
# download: s3://mousebraindata-open/MD657/patches/patches68.npz to ../../../../dev/shm/data/patches68.npz
# /dev/shm/data/patches68.npz
# 123 (12562156, 41, 41)
# patches69.npz
# download: s3://mousebraindata-open/MD657/patches/patches69.npz to ../../../../dev/shm/data/patches69.npz
# /dev/shm/data/patches69.npz
# 124 (12647456, 41, 41)
# patches7.npz
# download: s3://mousebraindata-open/MD657/patches/patches7.npz to ../../../../dev/shm/data/patches7.npz
# /dev/shm/data/patches7.npz
# 125 (12761537, 41, 41)
# patches70.npz
# download: s3://mousebraindata-open/MD657/patches/patches70.npz to ../../../../dev/shm/data/patches70.npz
# /dev/shm/data/patches70.npz
# 126 (12850595, 41, 41)
# patches71.npz
# download: s3://mousebraindata-open/MD657/patches/patches71.npz to ../../../../dev/shm/data/patches71.npz
# /dev/shm/data/patches71.npz
# 127 (12942572, 41, 41)
# patches72.npz
# download: s3://mousebraindata-open/MD657/patches/patches72.npz to ../../../../dev/shm/data/patches72.npz
# /dev/shm/data/patches72.npz
# 128 (13030135, 41, 41)
# patches73.npz
# download: s3://mousebraindata-open/MD657/patches/patches73.npz to ../../../../dev/shm/data/patches73.npz
# /dev/shm/data/patches73.npz
# 129 (13117963, 41, 41)
# patches74.npz
# download: s3://mousebraindata-open/MD657/patches/patches74.npz to ../../../../dev/shm/data/patches74.npz
# /dev/shm/data/patches74.npz

# %% [raw]
# patches=[]
# filenames=glob(data_dir+'/patches*.npz')
# for file in filenames:
#     print(file)
#     content=np.load(file)
#     patches.append(content['Vout'])
#
# combined=np.concatenate(patches[:1])
# combined.size/1000000.

# %%
patches.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c5435f0a016f> in <module>
# ----> 1 patches.shape
#
# NameError: name 'patches' is not defined

# %%
def permute(data):
    shuffle=np.random.permutation(data.shape[0])
    return data[shuffle,:,:]
scombined=permute(combined)
combined=[]
scombined.shape
# Out:
# (110124, 41, 41)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/yoavfreund/anaconda3/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['convolve']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
import matplotlib.pyplot as plt
from astropy.convolution import Gaussian2DKernel,convolve
gaussian = Gaussian2DKernel(1,x_size=7,y_size=7)
factor=sum(gaussian)
print('factor=',factor)
def calc_err(pic):
    P=convolve(pic,gaussian)/factor
    error=sqrt(mean(abs(pic-P)))
    sub=P[::2,::2]
    return error,sub
# Out:
# factor= 0.9994587918263369

# %%
def plot_patches(data,h=40,w=15,_titles=[]):
    figure(figsize=(w*2,h*2))
    for i in range(h*w):
        if i>=data.shape[0]:
            break
        subplot(h,w,i+1);
        pic=data[i,:,:]
        #P=convolve(pic,gaussian)/factor

        fig=imshow(pic,cmap='gray')
        if(len(_titles)>i):
            plt.title(_titles[i])
        fig.axes.get_xaxis().set_visible(False)
        fig.axes.get_yaxis().set_visible(False)
#plot_patches(scombined,h=2,_titles=[str(i) for i in range(scombined.shape[0])])

# %%
#collect images that are pretty smooth
# reduce resolution by a factor of 2
low_err=[]
i=0
while len(low_err) <1000000:
    if i >= scombined.shape[0]:
        break
    pic=scombined[i,:,:]
    i+=1
    error,sub=calc_err(pic)
    if error<0.3:
        low_err.append(sub)
        j=len(low_err)
        if j%1000==0:
            print('\r',i,j,end='')

lcombined=np.stack(low_err)
lcombined.shape
# Out:
#  109450 44000
# (44260, 21, 21)

# %%
def pack_pics(Reps):
    size=Reps[0].shape[0]
    _len=len(Reps)
    Reps_mat=np.zeros([_len,size,size])
    for i in range(_len):
        Reps_mat[i,:,:]=Reps[i]
    return Reps_mat

# %% [raw]
# shift=2000
# selected=[]
# errors=[]
# i=0; j=0;
# while j < 50:
#     pic=scombined[i+shift,:,:]
#     i+=1
#     error,sub=calc_err(pic)
#     if error>0.3:
#         continue
#     j+=1
#     selected.append(pic)
#     errors.append('%4.2f'%error)
# plot_patches(pack_pics(selected),h=20,w=6,_titles=errors)

# %% [raw]
# #running local
# np.savez(open('reducedSize.npz','wb'),lcombined)
#
# !ls -l reducedSize.npz
#
# data = np.load(open('reducedSize.npz','rb'))
# lcombined=data['arr_0']

# %%
lcombined.shape
# Out:
# (44260, 21, 21)

# %%
def dist2(a,b):
    diff=(a-b)**2
    return sum(diff.flatten())

# %%
D=[]
for i in range(1,lcombined.shape[0]):
    D.append(dist2(lcombined[i,:,:],lcombined[i-1,:,:]))
    if i%1000==0:
        print('\r',i,end='')
# Out:
#  44000

# %%
hist(D,bins=100);

# %%
max(D)
# Out:
# 566.113740962712

# %%
def refineKmeans(data,Reps):
    new_Reps=[np.zeros(Reps[0].shape) for r in Reps]
    Reps_count=[0.0 for r in Reps]
    error=0
    for i in range(data.shape[0]): 
        patch=data[i,:,:]
        dists=[dist2(patch,r) for r in Reps]
        _argmin=argmin(dists)
        _min=min(dists)
        new_Reps[_argmin]+=patch
        Reps_count[_argmin]+=1
        error+=_min
    error /= data.shape[0]
    final_Reps=[]
    final_counts=[]
    for i in range(len(new_Reps)):
        if Reps_count[i]>5:
            final_Reps.append(new_Reps[i]/Reps_count[i])
            final_counts.append(Reps_count[i])
    return final_Reps,final_counts,error

# %%
def Kmeans(data,n=100,scale=550):
    Reps,Statistics = Kmeanspp(data,n,scale)
    for i in range(5):
        Reps,error = refineKmeans(data,Reps)
        print('refine iteration %2d, error=%7.3f'%(i,error))

# %%
def Kmeanspp(data,n=100,scale=550):
    Reps=[data[0,:,:]]

    Statistics=[]
    j=1
    for i in range(1,data.shape[0]): 
        _min=100000
        patch=data[i,:,:]
        for r in Reps:
            _min=min(_min,dist2(patch,r))
        Prob=_min/scale
        print('\r','i=%10d,  #reps=%10d  Prob=%8.6f'%(i,len(Reps),Prob),end='')
        Statistics.append((i,len(Reps),_min))
        if np.random.rand()<Prob:
            Reps.append(patch)
            j+=1
        if j>=n:
            break
    return Reps,Statistics

# %%
def plot_statistics(Statistics,alpha=0.05,_start=10): 
    N=[x[1] for x in Statistics]
    d=[x[2] for x in Statistics]

    s=mean(d[:_start])
    smoothed=[s]*_start
    for x in d[_start:]:
        s=(1-alpha)*s + alpha*x
        smoothed.append(s)
    loglog(N[_start:],smoothed[_start:])
    xlabel('N')
    ylabel('smoothed distance')
    grid(which='both')

# %%
N=300
scombined=permute(lcombined)
Reps, Statistics = Kmeanspp(scombined,n=N)
Reps_mat = pack_pics(Reps)
plot_patches(Reps_mat,h=5,w=10)
# Out:
#  i=       354,  #reps=        57  Prob=0.083414
#  i=       574,  #reps=        83  Prob=0.122916
#  i=      2819,  #reps=       299  Prob=0.117173

# %%
Reps_mat.shape
# Out:
# (300, 21, 21)

# %%
for i in range(1,4):
    new_Reps,Reps_count,error = refineKmeans(scombined[i*10000:(i+1)*10000,:,:],Reps)
    print(i,error,len(Reps_count))
    Reps_mat = pack_pics(new_Reps)
    plot_patches(Reps_mat,h=1,w=10,_titles=['%4d'%x for x in Reps_count])
    Reps=new_Reps
plot_patches(Reps_mat,h=10,w=10,_titles=['final_%4d'%x for x in Reps_count])
# Out:
# 1 52.03491433949451 234
# 2 40.05263726717781 234
# 3 38.449768751633705 234

# %% [markdown]
# ## Calculate laplacian random-walk matrix
#
# The matrix corresponds to a simple random walk on the individual examples  where the location of each example is replaced by the location of the corresponding representative.
#
# We use [pydiffmap](https://pydiffmap.readthedocs.io/en/master/)

# %%
L=len(new_Reps)
new_Reps[0].shape
data1D=np.concatenate([x.reshape([1,441]) for x in new_Reps])
data1D.shape
# Out:
# (234, 441)

# %%
dists=[]
for i in range(L):
    for j in range(i):
        dists.append(dist2(new_Reps[i],new_Reps[j]))
hist(dists);
title('distances between centroids')
# Out:
# Text(0.5,1,'distances between centroids')

# %% [raw]
# scombined.shape
# data1D=scombined.reshape([scombined.shape[0],-1])
# data1D.shape

# %%
from pydiffmap import diffusion_map as dm
# initialize Diffusion map object.
neighbor_params = {'n_jobs': -1, 'algorithm': 'ball_tree'}

mydmap = dm.DiffusionMap(n_evecs=50, k=20, epsilon=100.0, alpha=1.0, neighbor_params=neighbor_params)
# fit to data and return the diffusion map.
dmap = mydmap.fit_transform(data1D)

#%pylab inline
pylab.scatter(dmap[:,0],dmap[:,1]);

# %%
hist(Reps_count);
title('no. of examples per partition')
# Out:
# Text(0.5,1,'no. of examples per partition')

# %%
image_size=np.array(new_Reps[0].shape)
canvas_size=np.array([1000,1000])
_minx=min(dmap[:,0])
_maxx=max(dmap[:,0])
_miny=min(dmap[:,1])
_maxy=max(dmap[:,1])
shift_x = -_minx
scale_x = canvas_size[0]/(_maxx - _minx)
shift_y = -_miny
scale_y = canvas_size[1]/(_maxy - _miny)

x=[int((_x+shift_x)*scale_x) for _x in dmap[:,0]]
y=[int((_y+shift_y)*scale_y) for _y in dmap[:,1]]

canvas=2*np.ones(canvas_size+image_size)
for i in range(len(new_Reps)):
    if(Reps_count[i]>30):
        canvas[x[i]:x[i]+image_size[0],y[i]:y[i]+image_size[1]]=new_Reps[i]

# %%
figure(figsize=[40,40])
imshow(canvas,cmap='gray')

# %%
max(new_Reps[0].flatten())
# Out:
# 2.0300056627638945

# %%
from pydiffmap.visualization import embedding_plot, data_plot

embedding_plot(mydmap, scatter_kwargs = {'c': dmap[:,0], 'cmap': 'Spectral'})
data_plot(mydmap, dim=3, scatter_kwargs = {'cmap': 'Spectral'})

plt.show()

# %%
A=np.zeros([L,L])
for i in range(L):
    for j in range(L):
        w=exp(-dist2(new_Reps[i],new_Reps[j])/sigma2)
        A[i,j]=w * Reps_count[i]*Reps_count[j]

# %%
D=sum(A,axis=0)
D2=diag(1/sqrt(D))

NA=np.dot(D2,np.dot(A,D2))

w,v = np.linalg.eig(NA)
hist(NA.flatten(),bins=100);

# %%
i=0
print('eig no %3d eigval=%5.3f'%(i,w[i]))
sorted_v=sort(v[i,:])
order=argsort(v[i,:])
plot_patches(Reps_mat[order],h=10,w=10,_titles=['c_%1d=%6.3f'%(i,x) for x in sorted_v])
# Out:
# eig no   0 eigval=1.000

# %% [raw]
# for i in range(L):
#     for j in range(L):
#         print(' %0.1f'%v[i,j],end='')
#     print('')

# %%
plot(w[:10])

# %%
scatter(v[1,:],v[2,:])

# %%
# Out:
# array([ 0.0684984 , -0.09683269,  0.11339218, -0.02815852,  0.01356517,
#         0.09702805, -0.00497052, -0.07564519, -0.00303605,  0.05598154,
#        -0.02534961, -0.03255552,  0.25791296, -0.0872418 , -0.15506584,
#         0.07946524,  0.11814611,  0.15164217,  0.23466678,  0.13819341,
#        -0.14399507,  0.06415621,  0.07988999, -0.12789215,  0.08951426,
#         0.15532145,  0.07016862,  0.15460653, -0.08454734, -0.14527753,
#        -0.06276835,  0.1593729 , -0.13350627, -0.22839049,  0.01349753,
#         0.23846752,  0.00080144,  0.20678977,  0.11093939,  0.12488391,
#         0.01444126, -0.02112139,  0.05719365,  0.06418349, -0.223191  ,
#        -0.0173864 ,  0.23103086,  0.28240511, -0.01096971,  0.01018806,
#         0.02284379,  0.10457885, -0.05902885, -0.03521811, -0.006584  ,
#         0.09166308,  0.0113964 , -0.00891202, -0.01769475, -0.01585222,
#         0.03784947,  0.12000808,  0.07827504, -0.0363255 ,  0.02059863,
#         0.21839337, -0.03755787, -0.00354101, -0.02926716, -0.01996813,
#         0.14158843, -0.02799874, -0.0293638 , -0.00864875, -0.07924559,
#        -0.07899344, -0.02037013,  0.07932468, -0.06119688,  0.05988191,
#        -0.01964591,  0.015688  , -0.05779182,  0.03536444,  0.10607948,
#        -0.0629174 ,  0.02757623,  0.01893713,  0.0785389 ,  0.02289555,
#         0.01987608, -0.00861318,  0.06344597, -0.01328009, -0.00495622,
#         0.00790415, -0.01606503,  0.00687534])

# %%
v[2,:]
# Out:
# array([ 2.76030401e-02, -9.99369815e-01,  1.86132817e-02, -1.09338415e-02,
#         1.96145234e-03, -2.14331499e-03, -8.98918520e-04,  1.85929501e-03,
#         1.50086424e-03,  6.09601482e-04,  2.05811280e-03, -8.29983576e-04,
#        -2.32679127e-03, -7.05417265e-04,  5.70638293e-05,  3.19153459e-04,
#         2.21861093e-04, -1.49317035e-04,  3.95528026e-04, -5.57342638e-04,
#        -1.30430651e-03, -4.68911652e-04, -1.96314600e-04, -6.01913609e-04,
#        -1.81860647e-04, -1.19399305e-03, -6.41843880e-05, -1.20281315e-03])
